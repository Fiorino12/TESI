# %% [markdown]
# # In this file we calibrate the rHeston (flat fwd variance) model through the direct image based approach
# This is a one-step approach meaning that we don't go through the forward pass where we learn the **mapping** between **rHeston parameters** and the entire implied volatility **surface**, which in this case is on a fixed grid 8(maturities)x11(strikes). Instead here we train the network only for the calibration purpose, switching input and output in the forward pass, this way we can immediately perform the calibration with a single evaluation of the network: no posterior optimization required.
# Below we upload the dataset .

# %%
#Set the directory of stored dataset
import os
os.chdir("C:/Users/pc/Desktop/politecnico/TESI/mio codice/rHeston/pointwise")

# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

# Load the dataset
file_path = "rHestonflatFixedGridsDataset.csv"
df = pd.read_csv(file_path)

# Constants
options_per_set = 88  # number of options per parameter set

# Extract the number of parameter sets
num_sets = len(df) // options_per_set

# Extract the 4 rough Heston parameters (first 4 columns)
# Take one row every 88 rows (because parameters repeat for each option set)
xx = df.iloc[::options_per_set, :4].values  # shape will be (14032, 4)

# Extract implied volatilities
ivs_flat = df.iloc[:, 6].values

# Reshape implied volatilities into (num_sets, options_per_set) (14032, 88)
clean_ivs = ivs_flat.reshape(num_sets, options_per_set)

#define strikes and maturities
strikes=np.array([0.5,0.6,0.7,0.8,0.9,1.0,1.1,1.2,1.3,1.4,1.5 ])
maturities=np.array([0.1,0.3,0.6,0.9,1.2,1.5,1.8,2.0 ])

# Print results
print("Input (rHeston parameters) shape:", xx.shape)
print("Clean implied vols shape:", clean_ivs.shape)
print("\nFirst parameter set:", xx[0])
print("\nFirst row of implied vols (88 values):", clean_ivs[0])
# Out:
# Input (rHeston parameters) shape: (14032, 4)
# Clean implied vols shape: (14032, 88)
#
# First parameter set: [ 0.09988963  0.62535715 -0.26080363  0.07983231]
#
# First row of implied vols (88 values): [0.64872359 0.56231116 0.47992252 0.39814869 0.31445118 0.24115731
#  0.25596344 0.30325519 0.34646731 0.38411643 0.41719648 0.51537984
#  0.45118853 0.39080813 0.33253622 0.27665252 0.23363192 0.23405806
#  0.25966183 0.28742661 0.31308175 0.33626391 0.44664808 0.39416201
#  0.34551886 0.29980068 0.25807806 0.2279981  0.22455626 0.23979873
#  0.25928364 0.27845439 0.29630902 0.41103717 0.36474571 0.32231994
#  0.2831725  0.24850518 0.22426157 0.21978066 0.23028873 0.24552686
#  0.26127061 0.27628756 0.38759678 0.34544973 0.30716186 0.27231767
#  0.24212501 0.22136182 0.21649321 0.22423255 0.23680191 0.25026589
#  0.26341405 0.3703811  0.33130354 0.29607355 0.26436244 0.2373792
#  0.21894607 0.21401262 0.21993748 0.23053957 0.24237397 0.25411529
#  0.35689989 0.32024326 0.2874113  0.2581292  0.2335434  0.21685054
#  0.21191516 0.21655833 0.22568852 0.2362576  0.24692559 0.34933926
#  0.31404871 0.28255463 0.25460917 0.23135188 0.21558515 0.21065402
#  0.21460608 0.22302936 0.2328569  0.24290242]

# %% [markdown]
# # Let's have a look at the dataset and gain some more informations

# %%
import seaborn as sns

#INPUT (rHESTON PARAMETERS) ANALYSIS 

# rHeston parameter names (for clarity)
#H     ∈ [0.01, 0.25]        (Hurst exponent)
#ν     ∈ [0.15, 0.65]        (initial variance)
#ρ     ∈ [-0.7, -0.1]        (spot-vol correlation)
#ν₀    ∈ [0.005, 0.13]       (vol of variance)

param_names = [
    'H (Hurst exponent)',
    'ν (vol of variance)',
    'ρ (spot-vol correlation)',
    'ν₀ (initial variance)'
]


# Create DataFrame for statistical analysis
df_xx = pd.DataFrame(xx, columns=param_names)

# Descriptive statistics
print("\n=== rough HESTON PARAMETERS ANALYSIS (xx) ===")
print(df_xx.describe(percentiles=[0.01, 0.05, 0.95, 0.99]).round(4))

# Validate physical bounds
print("\n=== PHYSICAL BOUNDS ===")
# Validate physical bounds
print("\n=== PHYSICAL BOUNDS ===")
print(f"ν₀:    Min={df_xx.iloc[:,3].min():.4f}, Max={df_xx.iloc[:,3].max():.4f} (Expected: ~[0.005, 0.13])")
print(f"ρ:   Min={df_xx.iloc[:,2].min():.4f}, Max={df_xx.iloc[:,2].max():.4f} (Expected: ~[-0.7, -0.1])")
print(f"H: Min={df_xx.iloc[:,0].min():.4f}, Max={df_xx.iloc[:,0].max():.4f} (Expected: ~[0.01, 0.25])")

# Plot distributions
plt.figure(figsize=(12, 6))
for i, col in enumerate(df_xx.columns):
    plt.subplot(2, 2, i+1)
    sns.histplot(df_xx[col], bins=50, kde=True)
    plt.title(col)
plt.tight_layout()
plt.show()

#OUTPUT (IMPLIED VOLATILTY SURFACE) ANALYSIS 
print("\n=== IMPLIED VOLATILITY SURFACE ANALYSIS (yy) ===")

# Global statistics
print(f"Global mean: {clean_ivs.mean():.4f}")
print(f"Global min: {clean_ivs.min():.4f}")
print(f"Global max: {clean_ivs.max():.4f}")

# Reshape first sample into strike/maturity matrix
vol_matrix = clean_ivs[0].reshape(len(maturities), len(strikes))
df_vol = pd.DataFrame(vol_matrix, index=maturities, columns=strikes)

print("\nVolatility matrix for strikes/maturities (first sample):")
print(df_vol.round(4))

# Create 3D plot
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')

# Create grid for surface plot
X, Y = np.meshgrid(strikes, maturities)

# Plot surface
surf = ax.plot_surface(X, Y, vol_matrix, cmap='viridis', edgecolor='none')

# Add color bar
fig.colorbar(surf, ax=ax, shrink=0.5, aspect=10, label='Implied Volatility')

# Set labels and title
ax.set_xlabel('Strike (Moneyness)')
ax.set_ylabel('Maturity (years)')
ax.set_zlabel('Implied Volatility')
ax.set_title('Implied Volatility Surface (first sample)')

# Adjust view angle for better visualization
ax.view_init(30, 45)

# Adjust layout to prevent clipping
plt.tight_layout(pad=4.0)
plt.subplots_adjust(left=0.1, right=0.9, bottom=0.1, top=0.9)

plt.show()
# Out:
# === rough HESTON PARAMETERS ANALYSIS (xx) ===
#        H (Hurst exponent)  ν (vol of variance)  ρ (spot-vol correlation)  \
# count          14032.0000           14032.0000                14032.0000
# mean               0.1229               0.4196                   -0.4120
# std                0.0679               0.1371                    0.1710
# min                0.0100               0.1501                   -0.7000
# 1%                 0.0118               0.1607                   -0.6941
# 5%                 0.0209               0.1929                   -0.6719
# 50%                0.1200               0.4249                   -0.4167
# 95%                0.2346               0.6274                   -0.1349
# 99%                0.2468               0.6457                   -0.1077
# max                0.2500               0.6499                   -0.1000
#
#        ν₀ (initial variance)
# count             14032.0000
# mean                  0.0716
# std                   0.0355
# min                   0.0050
# 1%                    0.0081
# 5%                    0.0136
# 50%                   0.0732
# 95%                   0.1247
# 99%                   0.1291
# max                   0.1300
#
# === PHYSICAL BOUNDS ===
#
# === PHYSICAL BOUNDS ===
# ν₀:    Min=0.0050, Max=0.1300 (Expected: ~[0.005, 0.13])
# ρ:   Min=-0.7000, Max=-0.1000 (Expected: ~[-0.7, -0.1])
# H: Min=0.0100, Max=0.2500 (Expected: ~[0.01, 0.25])
# === IMPLIED VOLATILITY SURFACE ANALYSIS (yy) ===
# Global mean: 0.2697
# Global min: 0.0305
# Global max: 0.8111
#
# Volatility matrix for strikes/maturities (first sample):
#         0.5     0.6     0.7     0.8     0.9     1.0     1.1     1.2     1.3  \
# 0.1  0.6487  0.5623  0.4799  0.3981  0.3145  0.2412  0.2560  0.3033  0.3465
# 0.3  0.5154  0.4512  0.3908  0.3325  0.2767  0.2336  0.2341  0.2597  0.2874
# 0.6  0.4466  0.3942  0.3455  0.2998  0.2581  0.2280  0.2246  0.2398  0.2593
# 0.9  0.4110  0.3647  0.3223  0.2832  0.2485  0.2243  0.2198  0.2303  0.2455
# 1.2  0.3876  0.3454  0.3072  0.2723  0.2421  0.2214  0.2165  0.2242  0.2368
# 1.5  0.3704  0.3313  0.2961  0.2644  0.2374  0.2189  0.2140  0.2199  0.2305
# 1.8  0.3569  0.3202  0.2874  0.2581  0.2335  0.2169  0.2119  0.2166  0.2257
# 2.0  0.3493  0.3140  0.2826  0.2546  0.2314  0.2156  0.2107  0.2146  0.2230
#
#         1.4     1.5
# 0.1  0.3841  0.4172
# 0.3  0.3131  0.3363
# 0.6  0.2785  0.2963
# 0.9  0.2613  0.2763
# 1.2  0.2503  0.2634
# 1.5  0.2424  0.2541
# 1.8  0.2363  0.2469
# 2.0  0.2329  0.2429

# %% [markdown]
# # Step 1: Data Generation
#
# ## **Inputs:**
# ### Implied volatility surface (8x11=88 points)
#
# ## **Outputs:**
# ###  1. $H$ Hurst exponent
# ###  2. $\gamma$ vol of variance
# ###  3. $\rho$ spot-vol correlation
# ###  4. $\nu_{0}$ inital variance

# %% [markdown]
# # Scaling:
#
# # Output Model Parameters ${\theta}_{i=1,..,4}\to scale(\theta_i)\in[-1,1]$ (suitable for tanh activation)
# ## $scale(\theta_i)=\frac{2\theta_i-(\theta_i^{max}+\theta_i^{min})}{\theta_i^{max}-\theta_i^{min}},\quad i \in |\Theta|$
#
# # Implied volatilities input scaling
# ## $$scale(\sigma^{BS}_{i,j})=\frac{\sigma^{BS}_{i,j}-\mathbb{E}[\sigma^{BS}_{i,j}]}{std(\sigma^{BS}_{i,j})},\quad i\in\text{Maturities},\; j\in \text{Strikes}$$

# %%
#Train+val(90%)-test(10%) split of data 
from sklearn.model_selection import train_test_split
from tabulate import tabulate

y_train_val, y_test, X_train_val, X_test = train_test_split(
    xx, clean_ivs, test_size=0.1, random_state=42)

#Train(85%)-val(15%) split of data 
X_train, X_val, y_train, y_val = train_test_split(
    X_train_val, y_train_val, test_size=0.11, random_state=42)

#data preprocessing (scaling)
from sklearn.preprocessing import StandardScaler

#1- Apply standard (z-score) scaling to input volatilities
#  to train, validation and test data (clearly without recomputing mu and sigma for validation and test data)
scaler_X = StandardScaler()
x_train_transform = scaler_X.fit_transform(X_train)  #we compute mu and sigma
x_val_transform = scaler_X.transform(X_val)  
x_test_transform = scaler_X.transform(X_test)

#define the inverse transform of data to bring volatilities back to original values
def Xinversetransform(x):
    return scaler_X.inverse_transform(x)

# ========================================================================
#2-Custom [-1,1] rHeston parameter scaling, define rHeston parameter's upper and lower bounds
# ===============================================================================
#H     ∈ [0.01, 0.25]        (Hurst exponent)
#ν     ∈ [0.15, 0.65]        (initial variance)
#ρ     ∈ [-0.7, -0.1]        (spot-vol correlation)
#ν₀    ∈ [0.005, 0.13]       (vol of variance)

#parameters order is: [H, ν, ρ, ν₀]

ub=np.array([0.25,0.65,-0.1,0.13])
lb=np.array([0.01,0.15,-0.7,0.005])

#define the direct and inverse map (as described above)
def myscale(x):
    res=np.zeros(x.shape)
    for i in range(x.shape[1]):
        res[:,i]=(2*x[:,i] - (ub[i] + lb[i])) / (ub[i] - lb[i])
        
    return res

def myinverse(x):
    res=np.zeros(x.shape)
    for i in range(x.shape[1]):
        res[:,i]=x[:,i] * (ub[i] - lb[i]) * 0.5 + (ub[i] + lb[i]) * 0.5
        
    return res

#scale parameters in training, validation and test set
y_train_transform = myscale(y_train)
y_val_transform = myscale(y_val)
y_test_transform = myscale(y_test)

# Print dataset shapes in a table
shape_data = [
    ["Training", x_train_transform.shape, y_train_transform.shape],
    ["Validation", x_val_transform.shape, y_val_transform.shape],
    ["Test", x_test_transform.shape, y_test_transform.shape]
]

print("\nDataset Shapes Summary:")
print(tabulate(shape_data, 
               headers=["Dataset", "Input Surfaces Shape", "Target Parameters Shape"],
               tablefmt="grid"))
# Out:
# Dataset Shapes Summary:
# +------------+------------------------+---------------------------+
# | Dataset    | Input Surfaces Shape   | Target Parameters Shape   |
# +============+========================+===========================+
# | Training   | (11238, 88)            | (11238, 4)                |
# +------------+------------------------+---------------------------+
# | Validation | (1390, 88)             | (1390, 4)                 |
# +------------+------------------------+---------------------------+
# | Test       | (1404, 88)             | (1404, 4)                 |
# +------------+------------------------+---------------------------+

# %% [markdown]
# # Let's see if the scaling has been correctly applied

# %%
# ----------------------------------------------------------------------------------
# 1. Verify INPUT Scaling (X: Implied Volatilities - StandardScaler)
# ----------------------------------------------------------------------------------
def check_X_scaling(X_train, X_val, X_test, x_train_transform, x_val_transform, x_test_transform):
    # Calculate statistics for each set
    stats_train = {
        "Set": "Train",
        "Mean": np.mean(x_train_transform, axis=0).round(3)[0],
        "Std": np.std(x_train_transform, axis=0).round(3)[0],
        "Min": np.min(x_train_transform).round(3),
        "Max": np.max(x_train_transform).round(3),
        "Inverse Check": np.allclose(X_train, Xinversetransform(x_train_transform))
    }
    
    stats_val = {
        "Set": "Validation",
        "Mean": np.mean(x_val_transform, axis=0).round(3)[0],
        "Std": np.std(x_val_transform, axis=0).round(3)[0],
        "Min": np.min(x_val_transform).round(3),
        "Max": np.max(x_val_transform).round(3),
        "Inverse Check": np.allclose(X_val, Xinversetransform(x_val_transform))
    }
    
    stats_test = {
        "Set": "Test",
        "Mean": np.mean(x_test_transform, axis=0).round(3)[0],
        "Std": np.std(x_test_transform, axis=0).round(3)[0],
        "Min": np.min(x_test_transform).round(3),
        "Max": np.max(x_test_transform).round(3),
        "Inverse Check": np.allclose(X_test, Xinversetransform(x_test_transform))
    }
    
    # Create table
    df_X = pd.DataFrame([stats_train, stats_val, stats_test])
    print("\n=== IMPLIED VOLATILITIES SCALING (StandardScaler) ===")
    print(tabulate(df_X, headers='keys', tablefmt='pretty', showindex=False))

# ----------------------------------------------------------------------------------
# 2. Verify OUTPUT Scaling (yy: rHeston Parameters - Custom [-1,1])
# ----------------------------------------------------------------------------------
def check_yy_scaling(y_train, y_val, y_test, y_train_transform, y_val_transform, y_test_transform):
    # Parameter names
    param_names = ["H", "ν", "ρ", "ν₀"]
    
    # Calculate min/max after scaling and check bounds
    data = {
        "Parameter": param_names,
        "Original Min": [y_train[:,i].min().round(4) for i in range(4)],
        "Original Max": [y_train[:,i].max().round(4) for i in range(4)],
        "Scaled Min (Train)": [y_train_transform[:,i].min().round(4) for i in range(4)],
        "Scaled Max (Train)": [y_train_transform[:,i].max().round(4) for i in range(4)],
    }
    
    df_yy = pd.DataFrame(data)
    print("\n=== rBergomi PARAMETERS SCALING (Custom [-1,1]) ===")
    print(tabulate(df_yy, headers='keys', tablefmt='pretty', showindex=False))
    
    print("\n=== VERIFY INVERSE TRANSFORMATION OF SCALED rHeston PARAMETERS (xx) ===")
    print(f"Train: {np.allclose(y_train, myinverse(y_train_transform))}")
    print(f"Val:   {np.allclose(y_val, myinverse(y_val_transform))}")
    print(f"Test:  {np.allclose(y_test, myinverse(y_test_transform))}")

    # Global check: All scaled values must be in [-1, 1]
    assert np.all(y_train_transform >= -1) and np.all(y_train_transform <= 1), "Some values are outside [-1,1]!"
    print("\n✔ All scaled parameters are within [-1,1]")

# ----------------------------------------------------------------------------------
# Run checks
# ----------------------------------------------------------------------------------
check_yy_scaling(y_train, y_val, y_test, y_train_transform, y_val_transform, y_test_transform)
check_X_scaling(X_train, X_val, X_test, x_train_transform, x_val_transform, x_test_transform)
# Out:
# === rBergomi PARAMETERS SCALING (Custom [-1,1]) ===
# +-----------+--------------+--------------+--------------------+--------------------+
# | Parameter | Original Min | Original Max | Scaled Min (Train) | Scaled Max (Train) |
# +-----------+--------------+--------------+--------------------+--------------------+
# |     H     |     0.01     |     0.25     |      -0.9997       |       0.9999       |
# |     ν     |    0.1501    |    0.6499    |      -0.9998       |       0.9996       |
# |     ρ     |     -0.7     |     -0.1     |        -1.0        |       0.9998       |
# |    ν₀     |    0.005     |     0.13     |      -0.9992       |       0.9998       |
# +-----------+--------------+--------------+--------------------+--------------------+
#
# === VERIFY INVERSE TRANSFORMATION OF SCALED rHeston PARAMETERS (xx) ===
# Train: True
# Val:   True
# Test:  True
#
# ✔ All scaled parameters are within [-1,1]
#
# === IMPLIED VOLATILITIES SCALING (StandardScaler) ===
# +------------+--------+-------+--------+-------+---------------+
# |    Set     |  Mean  |  Std  |  Min   |  Max  | Inverse Check |
# +------------+--------+-------+--------+-------+---------------+
# |   Train    |  -0.0  |  1.0  | -3.069 | 4.048 |     True      |
# | Validation | -0.027 | 0.991 | -2.65  | 3.256 |     True      |
# |    Test    | -0.029 | 1.005 | -2.951 | 3.485 |     True      |
# +------------+--------+-------+--------+-------+---------------+

# %% [markdown]
# # CaNN: Calibration Neural Network
# Now we can directly train the network to **calibrate** the rHeston parameters, learning the mapping from: implied volatility surface -> rHeston parameters. We can set up our neural network composed of:
#
# - **4 hidden layers**, each with **30 neurons**
# - **output layer** with 4 neurons (parameters space dimension), here we select a **tanh** activation function since we scaled the parameters into [-1,1] interval
# - **Activation function**: **Elu** , $\sigma_{Elu}=\alpha(e^x -1)$ in all the layers, its smoothness is crucial for the approximation of the Loss function
# - **Batch size**: **256**
# - **Optimizer**: **Adam**
# - **Early stopping**: with patience set to 40 epochs
# - **Loss**: MSE

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import EarlyStopping

# Set precision to float64
tf.keras.backend.set_floatx('float64')
tf.random.set_seed(42)  # For consistent initialization

# Build the model
inputs = Input(shape=(88,), name='input_layer')
x1 = Dense(30, activation='elu', name='hidden_1')(inputs)
x2 = Dense(30, activation='elu', name='hidden_2')(x1) 
x3 = Dense(30, activation='elu', name='hidden_3')(x2) 
x4 = Dense(30, activation='elu', name='hidden_4')(x3)
outputs = Dense(4, activation='tanh', name='output_layer')(x4)

modeldirect = Model(inputs=inputs, outputs=outputs, name = 'direct_model')
modeldirect.summary()
# Out:
# Model: "direct_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 88)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ hidden_1 (Dense)                │ (None, 30)             │         2,670 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ hidden_2 (Dense)                │ (None, 30)             │           930 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ hidden_3 (Dense)                │ (None, 30)             │           930 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ hidden_4 (Dense)                │ (None, 30)             │           930 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_layer (Dense)            │ (None, 4)              │           124 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,584 (43.62 KB)
#  Trainable params: 5,584 (43.62 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# **Train the model**

# %%
import time
# EarlyStopping callback
earlystop = EarlyStopping(
    monitor='val_loss', 
    patience=40,       
    verbose=1,       
    restore_best_weights=True  # Restore the best model weights
)

# Callbacks
#reduce_lr = ReduceLROnPlateau(
#        monitor='val_loss',
#        factor=0.5,
#        patience=20,
#        min_lr=5e-5,
 #       verbose=1
 #   )

# Compile the model
modeldirect.compile(loss="mse", optimizer="adam")

# Train the model
start=time.time()
history = modeldirect.fit(
    x_train_transform, 
    y_train_transform, 
    batch_size=256,
    validation_data=(x_val_transform, y_val_transform),
    epochs=400, 
    verbose=1, 
    shuffle=True, 
    callbacks=[earlystop]
)
end=time.time()
training_time=(end-start)
print("Training time :" ,training_time , "s" )

# Plot training history
plt.figure(figsize=(12, 8))  
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.yscale('log')
plt.title('direct calibration network Training History - Loss (MSE)')
plt.xlabel('Epoch')
plt.ylabel('Loss (log scale)')
plt.legend()
plt.grid(True, which="both", ls="--")
plt.show()

# Print final metrics
final_train_loss = history.history['loss'][-1]
final_val_loss = history.history['val_loss'][-1]
print(f"\nFinal Training Loss: {final_train_loss:.4e}")
print(f"Final Validation Loss: {final_val_loss:.4e}")
# Out:
# Epoch 1/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1651 - val_loss: 0.0310
# Epoch 2/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0224 - val_loss: 0.0134
# Epoch 3/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0123 - val_loss: 0.0108
# Epoch 4/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0102 - val_loss: 0.0091
# Epoch 5/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0089 - val_loss: 0.0080
# Epoch 6/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0079 - val_loss: 0.0073
# Epoch 7/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0072 - val_loss: 0.0067
# Epoch 8/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0065 - val_loss: 0.0062
# Epoch 9/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0060 - val_loss: 0.0057
# Epoch 10/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0056 - val_loss: 0.0053
# Epoch 11/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0052 - val_loss: 0.0050
# Epoch 12/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0049 - val_loss: 0.0047
# Epoch 13/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0047 - val_loss: 0.0044
# Epoch 14/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0044 - val_loss: 0.0042
# Epoch 15/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0042 - val_loss: 0.0040
# Epoch 16/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0040 - val_loss: 0.0038
# Epoch 17/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0039 - val_loss: 0.0037
# Epoch 18/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0037 - val_loss: 0.0036
# Epoch 19/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0036 - val_loss: 0.0034
# Epoch 20/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0034 - val_loss: 0.0033
# Epoch 21/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - val_loss: 0.0032
# Epoch 22/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - val_loss: 0.0031
# Epoch 23/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0031 - val_loss: 0.0030
# Epoch 24/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - val_loss: 0.0029
# Epoch 25/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - val_loss: 0.0029
# Epoch 26/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - val_loss: 0.0028
# Epoch 27/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 28/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 29/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 30/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 31/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 32/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 33/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 34/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 35/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 36/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 37/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 38/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 39/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 40/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 41/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 42/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 43/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 44/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 45/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 46/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 47/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 48/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 49/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 50/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 51/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 52/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 53/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 54/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 55/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 56/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 57/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 58/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 59/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 60/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 61/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 62/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 63/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 64/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 65/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 66/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 67/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 68/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 69/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 70/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 71/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 72/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 73/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 74/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 75/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 76/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 77/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 78/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 79/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 80/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 81/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 82/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 83/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 84/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 85/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 86/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 87/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 88/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 89/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 90/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 91/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 92/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 93/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 94/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 95/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 96/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 97/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 98/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 99/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 100/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 101/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 102/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 103/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 104/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 105/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 106/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 107/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 108/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 109/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 110/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 111/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 112/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 113/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 114/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0010 - val_loss: 9.7959e-04
# Epoch 115/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.8806e-04 - val_loss: 9.5529e-04
# Epoch 116/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.6623e-04 - val_loss: 9.3120e-04
# Epoch 117/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.4332e-04 - val_loss: 9.0760e-04
# Epoch 118/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.1942e-04 - val_loss: 8.8515e-04
# Epoch 119/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.9484e-04 - val_loss: 8.6468e-04
# Epoch 120/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.7001e-04 - val_loss: 8.4673e-04
# Epoch 121/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.4543e-04 - val_loss: 8.3147e-04
# Epoch 122/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.2156e-04 - val_loss: 8.1843e-04
# Epoch 123/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.9875e-04 - val_loss: 8.0658e-04
# Epoch 124/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.7723e-04 - val_loss: 7.9498e-04
# Epoch 125/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.5726e-04 - val_loss: 7.8296e-04
# Epoch 126/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.3912e-04 - val_loss: 7.7037e-04
# Epoch 127/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.2315e-04 - val_loss: 7.5797e-04
# Epoch 128/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.0973e-04 - val_loss: 7.4669e-04
# Epoch 129/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.9897e-04 - val_loss: 7.3697e-04
# Epoch 130/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.9057e-04 - val_loss: 7.2852e-04
# Epoch 131/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.8387e-04 - val_loss: 7.2079e-04
# Epoch 132/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.7809e-04 - val_loss: 7.1321e-04
# Epoch 133/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.7258e-04 - val_loss: 7.0537e-04
# Epoch 134/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.6699e-04 - val_loss: 6.9711e-04
# Epoch 135/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.6119e-04 - val_loss: 6.8847e-04
# Epoch 136/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.5522e-04 - val_loss: 6.7963e-04
# Epoch 137/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.4916e-04 - val_loss: 6.7084e-04
# Epoch 138/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.4311e-04 - val_loss: 6.6243e-04
# Epoch 139/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.3719e-04 - val_loss: 6.5455e-04
# Epoch 140/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.3143e-04 - val_loss: 6.4725e-04
# Epoch 141/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.2585e-04 - val_loss: 6.4050e-04
# Epoch 142/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.2045e-04 - val_loss: 6.3424e-04
# Epoch 143/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1521e-04 - val_loss: 6.2841e-04
# Epoch 144/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.1011e-04 - val_loss: 6.2291e-04
# Epoch 145/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.0514e-04 - val_loss: 6.1766e-04
# Epoch 146/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.0026e-04 - val_loss: 6.1261e-04
# Epoch 147/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.9546e-04 - val_loss: 6.0771e-04
# Epoch 148/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.9076e-04 - val_loss: 6.0298e-04
# Epoch 149/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8614e-04 - val_loss: 5.9835e-04
# Epoch 150/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8157e-04 - val_loss: 5.9384e-04
# Epoch 151/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.7708e-04 - val_loss: 5.8943e-04
# Epoch 152/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.7267e-04 - val_loss: 5.8511e-04
# Epoch 153/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6835e-04 - val_loss: 5.8090e-04
# Epoch 154/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6410e-04 - val_loss: 5.7675e-04
# Epoch 155/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.5994e-04 - val_loss: 5.7266e-04
# Epoch 156/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.5584e-04 - val_loss: 5.6862e-04
# Epoch 157/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.5181e-04 - val_loss: 5.6464e-04
# Epoch 158/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4786e-04 - val_loss: 5.6072e-04
# Epoch 159/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.4396e-04 - val_loss: 5.5686e-04
# Epoch 160/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4014e-04 - val_loss: 5.5308e-04
# Epoch 161/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3638e-04 - val_loss: 5.4936e-04
# Epoch 162/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.3268e-04 - val_loss: 5.4572e-04
# Epoch 163/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2902e-04 - val_loss: 5.4215e-04
# Epoch 164/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2542e-04 - val_loss: 5.3867e-04
# Epoch 165/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2187e-04 - val_loss: 5.3522e-04
# Epoch 166/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1837e-04 - val_loss: 5.3182e-04
# Epoch 167/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1492e-04 - val_loss: 5.2848e-04
# Epoch 168/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1153e-04 - val_loss: 5.2520e-04
# Epoch 169/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0819e-04 - val_loss: 5.2198e-04
# Epoch 170/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0491e-04 - val_loss: 5.1884e-04
# Epoch 171/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0167e-04 - val_loss: 5.1579e-04
# Epoch 172/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9848e-04 - val_loss: 5.1281e-04
# Epoch 173/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9535e-04 - val_loss: 5.0995e-04
# Epoch 174/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9226e-04 - val_loss: 5.0720e-04
# Epoch 175/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8922e-04 - val_loss: 5.0454e-04
# Epoch 176/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8623e-04 - val_loss: 5.0200e-04
# Epoch 177/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8331e-04 - val_loss: 4.9953e-04
# Epoch 178/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8043e-04 - val_loss: 4.9710e-04
# Epoch 179/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7760e-04 - val_loss: 4.9470e-04
# Epoch 180/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7480e-04 - val_loss: 4.9227e-04
# Epoch 181/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7204e-04 - val_loss: 4.8978e-04
# Epoch 182/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6931e-04 - val_loss: 4.8722e-04
# Epoch 183/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6661e-04 - val_loss: 4.8457e-04
# Epoch 184/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6394e-04 - val_loss: 4.8184e-04
# Epoch 185/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6129e-04 - val_loss: 4.7901e-04
# Epoch 186/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5867e-04 - val_loss: 4.7609e-04
# Epoch 187/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5607e-04 - val_loss: 4.7311e-04
# Epoch 188/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5350e-04 - val_loss: 4.7008e-04
# Epoch 189/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5095e-04 - val_loss: 4.6702e-04
# Epoch 190/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4843e-04 - val_loss: 4.6392e-04
# Epoch 191/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4593e-04 - val_loss: 4.6082e-04
# Epoch 192/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4345e-04 - val_loss: 4.5773e-04
# Epoch 193/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4098e-04 - val_loss: 4.5467e-04
# Epoch 194/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3855e-04 - val_loss: 4.5163e-04
# Epoch 195/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3615e-04 - val_loss: 4.4863e-04
# Epoch 196/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3377e-04 - val_loss: 4.4567e-04
# Epoch 197/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3142e-04 - val_loss: 4.4276e-04
# Epoch 198/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2909e-04 - val_loss: 4.3992e-04
# Epoch 199/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2679e-04 - val_loss: 4.3712e-04
# Epoch 200/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2451e-04 - val_loss: 4.3440e-04
# Epoch 201/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2225e-04 - val_loss: 4.3175e-04
# Epoch 202/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2002e-04 - val_loss: 4.2915e-04
# Epoch 203/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1781e-04 - val_loss: 4.2661e-04
# Epoch 204/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1563e-04 - val_loss: 4.2413e-04
# Epoch 205/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1348e-04 - val_loss: 4.2169e-04
# Epoch 206/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1135e-04 - val_loss: 4.1931e-04
# Epoch 207/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0923e-04 - val_loss: 4.1698e-04
# Epoch 208/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0710e-04 - val_loss: 4.1471e-04
# Epoch 209/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0499e-04 - val_loss: 4.1249e-04
# Epoch 210/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0290e-04 - val_loss: 4.1033e-04
# Epoch 211/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0084e-04 - val_loss: 4.0822e-04
# Epoch 212/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9879e-04 - val_loss: 4.0617e-04
# Epoch 213/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9678e-04 - val_loss: 4.0415e-04
# Epoch 214/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9479e-04 - val_loss: 4.0220e-04
# Epoch 215/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9280e-04 - val_loss: 4.0027e-04
# Epoch 216/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9083e-04 - val_loss: 3.9839e-04
# Epoch 217/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8888e-04 - val_loss: 3.9654e-04
# Epoch 218/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8693e-04 - val_loss: 3.9473e-04
# Epoch 219/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8499e-04 - val_loss: 3.9296e-04
# Epoch 220/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8307e-04 - val_loss: 3.9121e-04
# Epoch 221/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8113e-04 - val_loss: 3.8949e-04
# Epoch 222/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7920e-04 - val_loss: 3.8778e-04
# Epoch 223/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7728e-04 - val_loss: 3.8610e-04
# Epoch 224/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7537e-04 - val_loss: 3.8443e-04
# Epoch 225/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7346e-04 - val_loss: 3.8276e-04
# Epoch 226/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7153e-04 - val_loss: 3.8112e-04
# Epoch 227/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6962e-04 - val_loss: 3.7949e-04
# Epoch 228/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6773e-04 - val_loss: 3.7786e-04
# Epoch 229/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6582e-04 - val_loss: 3.7624e-04
# Epoch 230/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6390e-04 - val_loss: 3.7462e-04
# Epoch 231/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6199e-04 - val_loss: 3.7299e-04
# Epoch 232/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6008e-04 - val_loss: 3.7134e-04
# Epoch 233/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5815e-04 - val_loss: 3.6967e-04
# Epoch 234/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5621e-04 - val_loss: 3.6796e-04
# Epoch 235/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5426e-04 - val_loss: 3.6623e-04
# Epoch 236/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5232e-04 - val_loss: 3.6448e-04
# Epoch 237/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5038e-04 - val_loss: 3.6269e-04
# Epoch 238/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4843e-04 - val_loss: 3.6086e-04
# Epoch 239/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4646e-04 - val_loss: 3.5897e-04
# Epoch 240/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4448e-04 - val_loss: 3.5701e-04
# Epoch 241/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4252e-04 - val_loss: 3.5502e-04
# Epoch 242/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4055e-04 - val_loss: 3.5297e-04
# Epoch 243/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3856e-04 - val_loss: 3.5084e-04
# Epoch 244/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3655e-04 - val_loss: 3.4863e-04
# Epoch 245/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3453e-04 - val_loss: 3.4634e-04
# Epoch 246/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3249e-04 - val_loss: 3.4396e-04
# Epoch 247/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3043e-04 - val_loss: 3.4149e-04
# Epoch 248/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2836e-04 - val_loss: 3.3892e-04
# Epoch 249/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2627e-04 - val_loss: 3.3626e-04
# Epoch 250/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2418e-04 - val_loss: 3.3351e-04
# Epoch 251/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2208e-04 - val_loss: 3.3067e-04
# Epoch 252/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1998e-04 - val_loss: 3.2777e-04
# Epoch 253/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1788e-04 - val_loss: 3.2484e-04
# Epoch 254/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1579e-04 - val_loss: 3.2189e-04
# Epoch 255/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1371e-04 - val_loss: 3.1891e-04
# Epoch 256/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1163e-04 - val_loss: 3.1591e-04
# Epoch 257/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0956e-04 - val_loss: 3.1295e-04
# Epoch 258/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0753e-04 - val_loss: 3.1004e-04
# Epoch 259/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0552e-04 - val_loss: 3.0720e-04
# Epoch 260/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0354e-04 - val_loss: 3.0444e-04
# Epoch 261/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0159e-04 - val_loss: 3.0177e-04
# Epoch 262/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9967e-04 - val_loss: 2.9919e-04
# Epoch 263/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9779e-04 - val_loss: 2.9672e-04
# Epoch 264/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9595e-04 - val_loss: 2.9436e-04
# Epoch 265/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9416e-04 - val_loss: 2.9212e-04
# Epoch 266/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9241e-04 - val_loss: 2.8999e-04
# Epoch 267/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9070e-04 - val_loss: 2.8797e-04
# Epoch 268/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8903e-04 - val_loss: 2.8603e-04
# Epoch 269/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8741e-04 - val_loss: 2.8419e-04
# Epoch 270/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8582e-04 - val_loss: 2.8243e-04
# Epoch 271/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8427e-04 - val_loss: 2.8074e-04
# Epoch 272/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8275e-04 - val_loss: 2.7912e-04
# Epoch 273/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8125e-04 - val_loss: 2.7756e-04
# Epoch 274/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7978e-04 - val_loss: 2.7604e-04
# Epoch 275/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7833e-04 - val_loss: 2.7455e-04
# Epoch 276/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7689e-04 - val_loss: 2.7309e-04
# Epoch 277/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7546e-04 - val_loss: 2.7165e-04
# Epoch 278/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7405e-04 - val_loss: 2.7022e-04
# Epoch 279/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7264e-04 - val_loss: 2.6883e-04
# Epoch 280/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7125e-04 - val_loss: 2.6747e-04
# Epoch 281/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6987e-04 - val_loss: 2.6613e-04
# Epoch 282/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6850e-04 - val_loss: 2.6484e-04
# Epoch 283/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6714e-04 - val_loss: 2.6360e-04
# Epoch 284/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6580e-04 - val_loss: 2.6241e-04
# Epoch 285/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6448e-04 - val_loss: 2.6128e-04
# Epoch 286/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6316e-04 - val_loss: 2.6020e-04
# Epoch 287/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6184e-04 - val_loss: 2.5917e-04
# Epoch 288/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6054e-04 - val_loss: 2.5818e-04
# Epoch 289/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5924e-04 - val_loss: 2.5724e-04
# Epoch 290/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5795e-04 - val_loss: 2.5634e-04
# Epoch 291/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5668e-04 - val_loss: 2.5548e-04
# Epoch 292/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5541e-04 - val_loss: 2.5463e-04
# Epoch 293/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5416e-04 - val_loss: 2.5381e-04
# Epoch 294/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5291e-04 - val_loss: 2.5299e-04
# Epoch 295/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5168e-04 - val_loss: 2.5217e-04
# Epoch 296/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5044e-04 - val_loss: 2.5133e-04
# Epoch 297/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4922e-04 - val_loss: 2.5048e-04
# Epoch 298/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4800e-04 - val_loss: 2.4959e-04
# Epoch 299/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4678e-04 - val_loss: 2.4865e-04
# Epoch 300/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4555e-04 - val_loss: 2.4764e-04
# Epoch 301/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4434e-04 - val_loss: 2.4655e-04
# Epoch 302/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4312e-04 - val_loss: 2.4536e-04
# Epoch 303/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4189e-04 - val_loss: 2.4404e-04
# Epoch 304/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4067e-04 - val_loss: 2.4260e-04
# Epoch 305/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3946e-04 - val_loss: 2.4102e-04
# Epoch 306/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3826e-04 - val_loss: 2.3931e-04
# Epoch 307/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3710e-04 - val_loss: 2.3752e-04
# Epoch 308/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3600e-04 - val_loss: 2.3571e-04
# Epoch 309/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3497e-04 - val_loss: 2.3397e-04
# Epoch 310/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3403e-04 - val_loss: 2.3237e-04
# Epoch 311/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3320e-04 - val_loss: 2.3096e-04
# Epoch 312/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3246e-04 - val_loss: 2.2974e-04
# Epoch 313/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3179e-04 - val_loss: 2.2868e-04
# Epoch 314/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3117e-04 - val_loss: 2.2775e-04
# Epoch 315/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3058e-04 - val_loss: 2.2691e-04
# Epoch 316/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3000e-04 - val_loss: 2.2613e-04
# Epoch 317/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2940e-04 - val_loss: 2.2538e-04
# Epoch 318/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2879e-04 - val_loss: 2.2465e-04
# Epoch 319/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2815e-04 - val_loss: 2.2394e-04
# Epoch 320/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2749e-04 - val_loss: 2.2323e-04
# Epoch 321/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2681e-04 - val_loss: 2.2253e-04
# Epoch 322/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2611e-04 - val_loss: 2.2184e-04
# Epoch 323/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2540e-04 - val_loss: 2.2115e-04
# Epoch 324/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2467e-04 - val_loss: 2.2047e-04
# Epoch 325/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2394e-04 - val_loss: 2.1980e-04
# Epoch 326/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2321e-04 - val_loss: 2.1914e-04
# Epoch 327/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2247e-04 - val_loss: 2.1848e-04
# Epoch 328/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2173e-04 - val_loss: 2.1783e-04
# Epoch 329/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2100e-04 - val_loss: 2.1717e-04
# Epoch 330/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2026e-04 - val_loss: 2.1652e-04
# Epoch 331/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1953e-04 - val_loss: 2.1587e-04
# Epoch 332/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1880e-04 - val_loss: 2.1521e-04
# Epoch 333/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1807e-04 - val_loss: 2.1457e-04
# Epoch 334/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1735e-04 - val_loss: 2.1393e-04
# Epoch 335/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1664e-04 - val_loss: 2.1330e-04
# Epoch 336/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1594e-04 - val_loss: 2.1268e-04
# Epoch 337/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1524e-04 - val_loss: 2.1205e-04
# Epoch 338/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1455e-04 - val_loss: 2.1144e-04
# Epoch 339/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1387e-04 - val_loss: 2.1082e-04
# Epoch 340/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1319e-04 - val_loss: 2.1020e-04
# Epoch 341/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1251e-04 - val_loss: 2.0958e-04
# Epoch 342/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1184e-04 - val_loss: 2.0895e-04
# Epoch 343/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1117e-04 - val_loss: 2.0833e-04
# Epoch 344/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1050e-04 - val_loss: 2.0771e-04
# Epoch 345/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0984e-04 - val_loss: 2.0709e-04
# Epoch 346/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0918e-04 - val_loss: 2.0647e-04
# Epoch 347/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0852e-04 - val_loss: 2.0586e-04
# Epoch 348/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0786e-04 - val_loss: 2.0525e-04
# Epoch 349/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0721e-04 - val_loss: 2.0465e-04
# Epoch 350/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0655e-04 - val_loss: 2.0405e-04
# Epoch 351/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0590e-04 - val_loss: 2.0345e-04
# Epoch 352/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0526e-04 - val_loss: 2.0287e-04
# Epoch 353/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0462e-04 - val_loss: 2.0229e-04
# Epoch 354/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0398e-04 - val_loss: 2.0172e-04
# Epoch 355/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0335e-04 - val_loss: 2.0116e-04
# Epoch 356/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0273e-04 - val_loss: 2.0060e-04
# Epoch 357/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0211e-04 - val_loss: 2.0004e-04
# Epoch 358/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0150e-04 - val_loss: 1.9950e-04
# Epoch 359/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0089e-04 - val_loss: 1.9896e-04
# Epoch 360/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0029e-04 - val_loss: 1.9843e-04
# Epoch 361/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9969e-04 - val_loss: 1.9790e-04
# Epoch 362/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9909e-04 - val_loss: 1.9739e-04
# Epoch 363/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9850e-04 - val_loss: 1.9687e-04
# Epoch 364/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9792e-04 - val_loss: 1.9636e-04
# Epoch 365/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9733e-04 - val_loss: 1.9585e-04
# Epoch 366/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9675e-04 - val_loss: 1.9533e-04
# Epoch 367/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9616e-04 - val_loss: 1.9482e-04
# Epoch 368/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9558e-04 - val_loss: 1.9431e-04
# Epoch 369/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9500e-04 - val_loss: 1.9380e-04
# Epoch 370/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9443e-04 - val_loss: 1.9329e-04
# Epoch 371/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9386e-04 - val_loss: 1.9279e-04
# Epoch 372/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9329e-04 - val_loss: 1.9228e-04
# Epoch 373/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9272e-04 - val_loss: 1.9178e-04
# Epoch 374/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9216e-04 - val_loss: 1.9127e-04
# Epoch 375/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9160e-04 - val_loss: 1.9076e-04
# Epoch 376/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9105e-04 - val_loss: 1.9024e-04
# Epoch 377/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9049e-04 - val_loss: 1.8972e-04
# Epoch 378/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8994e-04 - val_loss: 1.8918e-04
# Epoch 379/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8940e-04 - val_loss: 1.8863e-04
# Epoch 380/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8887e-04 - val_loss: 1.8807e-04
# Epoch 381/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8834e-04 - val_loss: 1.8749e-04
# Epoch 382/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8782e-04 - val_loss: 1.8689e-04
# Epoch 383/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8730e-04 - val_loss: 1.8626e-04
# Epoch 384/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8680e-04 - val_loss: 1.8559e-04
# Epoch 385/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8631e-04 - val_loss: 1.8487e-04
# Epoch 386/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8582e-04 - val_loss: 1.8411e-04
# Epoch 387/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8534e-04 - val_loss: 1.8328e-04
# Epoch 388/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8487e-04 - val_loss: 1.8238e-04
# Epoch 389/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8439e-04 - val_loss: 1.8140e-04
# Epoch 390/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8390e-04 - val_loss: 1.8035e-04
# Epoch 391/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8340e-04 - val_loss: 1.7924e-04
# Epoch 392/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8288e-04 - val_loss: 1.7809e-04
# Epoch 393/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8233e-04 - val_loss: 1.7692e-04
# Epoch 394/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8176e-04 - val_loss: 1.7574e-04
# Epoch 395/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8116e-04 - val_loss: 1.7459e-04
# Epoch 396/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8053e-04 - val_loss: 1.7348e-04
# Epoch 397/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7987e-04 - val_loss: 1.7243e-04
# Epoch 398/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7921e-04 - val_loss: 1.7145e-04
# Epoch 399/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7854e-04 - val_loss: 1.7056e-04
# Epoch 400/400
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7786e-04 - val_loss: 1.6976e-04
# Restoring model weights from the end of the best epoch: 400.
# Training time : 75.19915437698364 s
# Final Training Loss: 1.8722e-04
# Final Validation Loss: 1.6976e-04

# %% [markdown]
# # Interpretability analysis through SHAP Values

# %%
import shap

# --- Rewrite strikes and maturities ---
strikes = np.array([0.5,0.6,0.7,0.8,0.9,1.0,1.1,1.2,1.3,1.4,1.5])
maturities = np.array([0.1,0.3,0.6,0.9,1.2,1.5,1.8,2.0])
n_strikes, n_matur = strikes.size, maturities.size
assert n_strikes * n_matur == 88

param_names = ["H", "γ", "ρ", "ν₀"]

# Smaller background to speed up
background = x_train_transform[np.random.choice(len(x_train_transform), size=1000, replace=False)]
background32 = background.astype(np.float32)
x_test32 = x_test_transform.astype(np.float32)

# --- GradientExplainer (without output_names) ---
explainer = shap.DeepExplainer(
    (modeldirect.input, modeldirect.output),
    background32
)

# Compute SHAP values on the test set
shap_exp = explainer(x_test32)

# Debugging: let's see the output shape
print("Shape of shap_exp.values:", np.array(shap_exp.values).shape)
print("Type of shap_exp.values:", type(shap_exp.values))

# Rearrange the dimensions to get (n_samples, n_outputs, n_features)
shap_values = shap_exp.values.transpose(0, 2, 1)  # (1404, 4, 88)

n_test, n_outputs, n_features = shap_values.shape
print(f"Final shape of shap_values: {shap_values.shape}")
assert n_outputs == len(param_names) and n_features == 88

# --- Mean absolute SHAP ---
mean_abs_shap = np.mean(np.abs(shap_values), axis=0)   # (4,88)
total_mean_abs_shap = mean_abs_shap.sum(axis=0)

# Labels
feature_labels = []
for T in maturities:
    for K in strikes:
        feature_labels.append(f"T={T:.1f} K={K:.1f}")
feature_labels = np.array(feature_labels)

# Sorting by total importance
order = np.argsort(total_mean_abs_shap)[::-1]
sorted_labels = feature_labels[order]
sorted_per_param = mean_abs_shap[:, order]

# --- Stacked bar plot with manual colors ---
plt.figure(figsize=(6, 8))
top_N = 10
y_positions = np.arange(top_N)
bottom = np.zeros(top_N)
colors = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728"]

for i in range(n_outputs):
    vals = sorted_per_param[i, :top_N]
    plt.barh(y_positions, vals, left=bottom, label=param_names[i], color=colors[i])
    bottom += vals

plt.yticks(y_positions, sorted_labels[:top_N])
plt.gca().invert_yaxis()
plt.xlabel("mean(|SHAP value|) (average impact on model output magnitude)")
plt.title("Top implied volatilities by mean absolute SHAP")
plt.legend(title="rHeston params")
plt.grid(axis='x', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# --- Saliency/Heatmaps maps ---
saliency_maps = mean_abs_shap.reshape((n_outputs, n_matur, n_strikes))  # (4,8,11)

fig, axes = plt.subplots(2, 2, figsize=(14, 10))
axes = axes.flatten()

for i in range(n_outputs):
    ax = axes[i]
    im = ax.imshow(saliency_maps[i], origin='lower', aspect='auto', cmap="viridis")
    ax.set_title(param_names[i], fontsize=14)
    ax.set_xlabel("Strike")
    ax.set_ylabel("Maturity")
    ax.set_xticks(np.arange(n_strikes))
    ax.set_xticklabels([f"{s}" for s in strikes])
    ax.set_yticks(np.arange(n_matur))
    ax.set_yticklabels([f"{t}" for t in maturities])
    cbar = fig.colorbar(im, ax=ax)
    cbar.set_label("mean(|SHAP|)")

fig.suptitle("Heatmaps (mean absolute SHAP)", fontsize=16)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()
# Out:
# c:\Users\pc\AppData\Local\Programs\Python\Python311\Lib\site-packages\shap\explainers\_deep\deep_tf.py:94: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn(
# Shape of shap_exp.values: (1404, 88, 4)
# Type of shap_exp.values: <class 'numpy.ndarray'>
# Final shape of shap_values: (1404, 4, 88)

# %% [markdown]
# # Evaluate the calibration network on test data
# We can already assess the performance of the calibration network, in fact since it's been trained on implied volatility surfaces, it's possible to assess the calibration performance on test data.

# %%
# Calculate predictions on preprocessed test implied volatility surfaces 
start=time.perf_counter()
y_pred_transformed = modeldirect.predict(x_test_transform)
calib_time = (time.perf_counter()-start)/x_test_transform.shape[0]
print("Calibration time (per surface):" , calib_time*1000 , "ms" )

# 1) Error on preprocessed test parameters (y_test_transform)
mse_transformed = np.mean(np.square(y_test_transform - y_pred_transformed))
rmse_transformed = np.sqrt(mse_transformed)

print("\nErrors on preprocessed test data:")
print(f"- MSE: {mse_transformed:.6f}")
print(f"- RMSE: {rmse_transformed:.6f}")

# 2) Error on original scale test parameters (inverse transformed)
y_pred_original = myinverse(y_pred_transformed)

mse_original = np.mean(np.square(y_test - y_pred_original))
rmse_original = np.sqrt(mse_original)

print("\nErrors on original scale test data:")
print(f"- MSE: {mse_original:.6f}")
print(f"- RMSE: {rmse_original:.6f}")
# Out:
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Calibration time (per surface): 0.24330113960125804 ms
#
# Errors on preprocessed test data:
# - MSE: 0.000149
# - RMSE: 0.012212
#
# Errors on original scale test data:
# - MSE: 0.000007
# - RMSE: 0.002596

# %% [markdown]
# # Optimizing the calibration
# Numpy Implementation of the Neural Network tends to be **faster** than Keras, in this way we can evaluate in a faster and more efficient way the calibration cutting further down the calibration time.
#
#  In particular we completely **eliminate** the Keras framework **overhead** for each predict call.
#
#  The following numpy implementations are specifically designed for single and batch surfaces calibration, every operation is vectorized, the batch version processes **all the surfaces at once** completely in parallel leveraging preallocation for efficient memory usage.
#
#  This leads to a **~40** faster calibration: only few µs per surface!

# %%
import scipy.optimize
import matplotlib.ticker as mtick

def extract_weights_from_keras_model(model):
    """
    Extract weights and bias from the trained keras network, format for Numpy usage
    """
    weights_and_biases = []
    
    # Extract weights and biases for each layer
    for layer in model.layers:
        if hasattr(layer, 'get_weights') and layer.get_weights():
            weights, biases = layer.get_weights()
            weights_and_biases.append([weights, biases])
    
    return weights_and_biases

# Extract parameters from your trained model
NNParameters = extract_weights_from_keras_model(modeldirect)

# =====================================================================================
# NUMPY IMPLEMENTATION OF THE DIRECT CALIBRATION NN (FASTER THAN KERAS)
# =====================================================================================

# Network hyperparameters
NumLayers = 4  # 4 hidden layers (30 neurons each)
InputSize = 88  # 88 volatility surface points
OutputSize = 4  # 4 rHeston parameters

def elu(x):
    """
    ELU activation function
    Args:
        x: input array
    Returns:
        ELU activated array
    """
    x = np.array(x, dtype=np.float64)
    return np.where(x < 0, np.exp(x) - 1, x)

def DirectCalibrationNN(x):
    """
    Forward pass of Direct Calibration Neural Network
    
    Args:
        volatility_surfaces: arrays of 88 volatility surface points (input)
    
    Returns:
        rHeston_params: array of 4 rHeston parameters 
    """
    # Forward pass through hidden layers with ELU activation
    for i in range(NumLayers):
        # Linear transformation: x = x * W + b
        x = np.dot(x, NNParameters[i][0]) + NNParameters[i][1]
        # ELU activation
        x = elu(x)
    
    # Output layer with tanh activation
    output = np.dot(x, NNParameters[NumLayers][0]) + NNParameters[NumLayers][1]
    output = np.tanh(output)
    
    return output

# =====================================================================================
# OPTIMIZED NUMPY IMPLEMENTATION FOR BATCH PROCESSING
# =====================================================================================

def batch_DirectCalibrationNN(volatility_surfaces):
    """
    Vectorized forward pass for batch processing
    
    Args:
        volatility_surfaces: array of shape (n_surfaces, 88) 
    Returns:
        rHeston_params: array of shape (n_surfaces, 4)
    """
    # Pre-allocate output array
    n_surfaces = volatility_surfaces.shape[0]
    output = np.zeros((n_surfaces, 4))
    
    # Batch processing through all layers
    x = volatility_surfaces.copy()
    for i in range(NumLayers):
        x = x @ NNParameters[i][0] + NNParameters[i][1]  # @ = matrix multiplication
        x = np.where(x < 0, np.exp(x) - 1, x)  # ELU activation
    
    # Output layer with tanh
    output = np.tanh(x @ NNParameters[NumLayers][0] + NNParameters[NumLayers][1])
    return output

# =====================================================================================
# BENCHMARKING OPTIMIZED VERSION
# =====================================================================================

def run_benchmark():
    # Warm-up runs (ensure fair timing)
    _ = batch_DirectCalibrationNN(x_test_transform[:10])
    
    # Time measurement
    start_time = time.perf_counter()
    calibrated_params = batch_DirectCalibrationNN(x_test_transform)
    total_time = (time.perf_counter() - start_time) * 1000  # Convert to ms
    
    n_surfaces = x_test_transform.shape[0]
    avg_time = total_time / n_surfaces
    
    print(f"\nBATCH CALIBRATION RESULTS (NumPy Optimized)")
    print("----------------------------------------")
    print(f"Total surfaces processed: {n_surfaces}")
    print(f"Total calibration time: {total_time:.2f} ms")
    print(f"Average time per surface: {avg_time*1000:.4f} µs")
    print(f"Throughput: {n_surfaces/(total_time/1000):.0f} surfaces/second")
    
    return calibrated_params

# Run benchmark
final_calibrated_params = run_benchmark()
# Out:
# BATCH CALIBRATION RESULTS (NumPy Optimized)
# ----------------------------------------
# Total surfaces processed: 1404
# Total calibration time: 4.26 ms
# Average time per surface: 3.0320 µs
# Throughput: 329817 surfaces/second

# %%
# COMPARISON KERAS VS NUMPY IMPLEMENTATION
# Generate predictions with both methods
keras_pred = modeldirect.predict(x_test_transform, verbose=0)
numpy_pred = batch_DirectCalibrationNN(x_test_transform)

# Compute absolute and relative differences
abs_diff = np.abs(keras_pred - numpy_pred)
rel_diff = abs_diff / (np.abs(keras_pred) + 1e-12)  # Avoid dividing by 0

# Stats
print("Compare predictions Keras vs NumPy:")
print(f"Max absolute difference: {np.max(abs_diff):.2e}")
print(f"Mean relative difference: {np.mean(rel_diff):.2%}")
print(f"Positions with >1% difference: {np.sum(rel_diff > 0.01)}/{rel_diff.size}")
print("Numpy and Keras predictions agree ✔")
# Out:
# Compare predictions Keras vs NumPy:
# Max absolute difference: 2.22e-15
# Mean relative difference: 0.00%
# Positions with >1% difference: 0/5616
# Numpy and Keras predictions agree ✔

# %% [markdown]
# # Complete test analysis

# %%
# Convert predictions to original scale
print(f"Surfaces parameters shape: {numpy_pred.shape}")  # Should be (1404,4)
calib_params = myinverse(numpy_pred)

# Verify dimensions
assert len(calib_params) == len(y_test), "Mismatch between calibrated parameters and test set"

# Plot relative errors for each parameter
titles = ["H", "γ", "ρ", "ν₀"]
relative_errors = np.zeros((len(calib_params), 4))  # Store all relative errors

fig = plt.figure(figsize=(14, 8))
for param_idx in range(4):
    ax = plt.subplot(2, 2, param_idx+1)
    
    # Get true and calibrated parameters
    true_params = y_test[:, param_idx]
    calibrated_params = calib_params[:, param_idx]
    
    # Calculate relative errors 
    with np.errstate(divide='ignore', invalid='ignore'):
        rel_errors = np.abs(calibrated_params - true_params) / np.abs(true_params)
    
    relative_errors[:, param_idx] = rel_errors
    
    # Plot
    plt.plot(true_params, 100 * rel_errors, 'b*', alpha=0.6)
    plt.title(titles[param_idx], fontsize=20)
    plt.xlabel('True Parameter Value', fontsize=12)
    plt.ylabel('Relative Error (%)', fontsize=12)
    plt.gca().yaxis.set_major_formatter(mtick.PercentFormatter())
    
    # Add statistics
    stats_text = 'Avg: %1.2f%%\nMed: %1.2f%%\nMax: %1.2f%%' % (
        np.mean(100 * rel_errors),
        np.median(100 * rel_errors),
        np.max(100 * rel_errors))
    
    plt.text(0.5, 0.85, stats_text,
             horizontalalignment='center',
             verticalalignment='center',
             transform=ax.transAxes,
             fontsize=14,
             bbox=dict(facecolor='white', alpha=0.8))

plt.suptitle('rough Heston (flat fwd variance) Model Parameter Calibration Errors (grid based)\n Direct Calibration Method', 
             fontsize=16, y=1.02)
plt.tight_layout()
plt.show()

# Additional analysis
print("\nSummary Statistics of Relative Errors (%):")
for i, title in enumerate(titles):
    print(f"{title}: Avg={np.mean(100*relative_errors[:,i]):.2f}%, "
          f"Med={np.median(100*relative_errors[:,i]):.2f}%, "
          f"Max={np.max(100*relative_errors[:,i]):.2f}%")
# Out:
# Surfaces parameters shape: (1404, 4)
# Summary Statistics of Relative Errors (%):
# H: Avg=2.20%, Med=0.79%, Max=67.31%
# ν: Avg=0.50%, Med=0.30%, Max=8.21%
# ρ: Avg=0.99%, Med=0.53%, Max=18.41%
# ν₀: Avg=0.89%, Med=0.49%, Max=23.81%

# %%
# Correct parameter names and absolute error analysis
titles = ["H", "γ", "ρ", "ν₀"]
absolute_errors = np.zeros((len(calib_params), 4))  # Store all absolute errors

fig = plt.figure(figsize=(14, 8))
for param_idx in range(4):
    ax = plt.subplot(2, 2, param_idx+1)
    
    # Get true and calibrated parameters
    true_params = y_test[:, param_idx]
    calibrated_params = calib_params[:, param_idx]
    
    # Calculate absolute errors
    abs_errors = np.abs(calibrated_params - true_params)
    absolute_errors[:, param_idx] = abs_errors
    
    # Plot
    plt.plot(true_params, abs_errors, 'b*', alpha=0.6)
    plt.title(titles[param_idx], fontsize=20)
    plt.xlabel('True Parameter Value', fontsize=12)
    plt.ylabel('Absolute Error', fontsize=12)
    
    # Add statistics
    stats_text = 'Avg: %1.4f\nMed: %1.4f\nMax: %1.4f' % (
        np.mean(abs_errors),
        np.median(abs_errors),
        np.max(abs_errors))
    
    plt.text(0.5, 0.85, stats_text,
             horizontalalignment='center',
             verticalalignment='center',
             transform=ax.transAxes,
             fontsize=14,
             bbox=dict(facecolor='white', alpha=0.8))

plt.suptitle('rough Heston (flat fwd variance) Model Parameter Calibration - Absolute Errors (grid based)\nDirect Calibration Method', 
             fontsize=16, y=1.02)
plt.tight_layout()
plt.show()

# Additional analysis
print("\nSummary Statistics of Absolute Errors:")
for i, title in enumerate(titles):
    print(f"{title}: Avg={np.mean(absolute_errors[:,i]):.6f}, "
          f"Med={np.median(absolute_errors[:,i]):.6f}, "
          f"Max={np.max(absolute_errors[:,i]):.6f}")
# Out:
# Summary Statistics of Absolute Errors:
# H: Avg=0.001245, Med=0.000917, Max=0.009308
# ν: Avg=0.001749, Med=0.001218, Max=0.018064
# ρ: Avg=0.002887, Med=0.002057, Max=0.027355
# ν₀: Avg=0.000428, Med=0.000314, Max=0.003217
